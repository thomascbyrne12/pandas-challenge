# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "C:\\Users\\Thomas Byrne\\Documents\\purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_df = pd.DataFrame(purchase_data)

# %%
purchase_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
total_players = pd.DataFrame({"Total Players": [purchase_df["Purchase ID"].count()]})

# %%
total_players
# Out:
#    Total Players
# 0            780

# %%
unique_items = purchase_df["Item Name"].nunique()
avg_price = purchase_df["Price"].mean()
total_purchases = purchase_df["Purchase ID"].count()
revenue = purchase_df["Price"].sum()
pd.options.display.float_format = '${:,.2f}'.format
summary_df  = pd.DataFrame({"Number of Unique Items": [unique_items], "Average Price": [avg_price],
                            "Number of Purchases": [total_purchases], "Total Revenue": [revenue]})

# %%
summary_df.head()
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179          $3.05                  780      $2,379.77

# %%
gender_total = purchase_df["Gender"].value_counts()
percents = purchase_df['Gender'].value_counts(normalize=True) * 100
pd.options.display.float_format = '{:,.2f}%'.format
gender_count = pd.DataFrame({"Total Count": gender_total, "Percentage of Players": percents})
gender_count
# Out:
#                        Total Count  Percentage of Players
# Male                           652                 83.59%
# Female                         113                 14.49%
# Other / Non-Disclosed           15                  1.92%

# %%
gender_df = purchase_df.groupby("Gender")
gender_avg = gender_df["Price"].mean()
gender_price = gender_df["Price"].sum()
unique_df = purchase_df.drop_duplicates("SN")
unique = unique_df["Gender"].value_counts()
avg_per_person = gender_price / unique
pd.options.display.float_format = '${:,.2f}'.format
gender_sort_df = pd.DataFrame({"Total Count": gender_total, "Average Purchase Price": gender_avg,
                                "Total Purchase Price": gender_price, 
                                "Average Purchase Price per Person": avg_per_person})
gender_sort_df
# Out:
#                        Total Count  Average Purchase Price  \
# Female                         113                   $3.20
# Male                           652                   $3.02
# Other / Non-Disclosed           15                   $3.35
#
#                        Total Purchase Price  Average Purchase Price per Person
# Female                              $361.94                              $4.47
# Male                              $1,967.64                              $4.07
# Other / Non-Disclosed                $50.19                              $4.56

# %%
unique
# Out:
# Male                     484
# Female                    81
# Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
bins = [1, 10, 14, 15, 20, 25, 30, 35, 40]
labels = ['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']
age_df = purchase_df.groupby('Age')
age_cut = pd.cut(age_df['Age'], bins=bins, labels=labels)
age_total = pd.cut(age_df['Age'], bins=bins).value_counts()
percents = pd.cut(age_df['Age'], bins=bins).value_counts(normalize=True) * 100
age_cut = age_cut.drop_duplicates('first')
age_cut = age_cut.dropna(how='any')
total_df = pd.DataFrame({'Age': age_cut, 'Total Count': age_total.values, 'Percentage of Players': percents.values})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-12e1fe378eaf> in <module>
#       2 labels = ['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']
#       3 age_df = purchase_df.groupby('Age')
# ----> 4 age_cut = pd.cut(age_df['Age'], bins=bins, labels=labels)
#       5 age_total = pd.cut(age_df['Age'], bins=bins).value_counts()
#       6 percents = pd.cut(age_df['Age'], bins=bins).value_counts(normalize=True) * 100
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     239                               include_lowest=include_lowest,
#     240                               dtype=dtype,
# --> 241                               duplicates=duplicates)
#     242
#     243     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# ...

# %%
age_df.head()
# Out:
#      Purchase ID              SN  Age                 Gender  Item ID  \
# 0              0         Lisim78   20                   Male      108
# 1              1     Lisovynya38   40                   Male      143
# 2              2      Ithergue48   24                   Male       92
# 3              3   Chamassasya86   24                   Male      100
# 4              4       Iskosia90   23                   Male      131
# 5              5         Yalae81   22                   Male       81
# 6              6       Itheria73   36                   Male      169
# 7              7     Iskjaskst81   20                   Male      162
# 8              8       Undjask33   22                   Male       21
# 9              9     Chanosian48   35  Other / Non-Disclosed      136
# 10            10       Inguron55   23                   Male       95
# 11            11    Haisrisuir60   23                   Male      162
# ...

# %%
bins = [1, 10, 14, 15, 20, 25, 30, 35, 40]
labels = ['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']
age_cut = pd.cut(purchase_df['Age'], bins=bins, labels=labels)
age_total = pd.cut(purchase_df['Age'], bins=bins).value_counts()
